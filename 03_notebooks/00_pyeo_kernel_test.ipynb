# %%
import sys
import pyeo
import pyeo.classification
from osgeo import gdal

print("Python:", sys.executable)
print("PyEO:", pyeo.__file__)
print("GDAL:", gdal.VersionInfo("RELEASE_NAME"))
print("Jupyter kernel test: PASS")
# Out:
# 2026-07-25 06:10:31,716: WARNING: Windows or iOS detected; Patching GetVirtualMemArray. Some functions may not respond as expected.
# Python: C:\Users\moses\miniconda3\envs\pyeo_env\python.exe
# PyEO: c:\gis\src\pyeo\pyeo\__init__.py
# GDAL: 3.4.3
# Jupyter kernel test: PASS
